# %% [markdown]
# # Investigations of Chebyshev cardinal functions

# %%
import numpy as np
import numpy.polynomial as poly
import matplotlib.pyplot as plt

# %% [markdown]
# ### Unconstrained Gaussian quadrature

# %%
def gauss_cheb(nodes):
    # Chebyshev nodal points
    s = np.arange(nodes)
    cheb_nodes = np.cos(np.pi * (2 * s + 1) / (2 * nodes))
    return cheb_nodes

def gc_cardinal(x, cheb_nodes):
    N = cheb_nodes.shape[0]
    return np.array([
        (poly.chebyshev.chebval(x, (*np.zeros(N), 1)) / 
        (N * np.sin(np.pi * (s + 0.5)) / np.sin(np.pi / N * (s + 0.5)) * (x-cheb_nodes[s]))) for s in range(N)
    ])

def lg_cardinal(x, N):
    nodes, weights = poly.legendre.leggauss(N)
    #     print(nodes)
    #     print(weights)
    #     print(np.array([poly.legendre.legval(nodes[s], (*np.zeros(N), 1)) for s in range(N)]))
    return np.array([
        weights[j] * sum((s + 0.5) * poly.legendre.legval(nodes[j], (*np.zeros(s), 1)) * 
                         poly.legendre.legval(x, (*np.zeros(s), 1)) for s in range(N))
        for j in range(N)])

x = np.linspace(-1, 1, num=100)

# %%
N = 3
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 4
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 5
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 6
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 7
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 8
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 9
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 10
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 12
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 13
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %%
N = 20
x = np.linspace(0.75, 1, num=1000)
cheb_nodes = gauss_cheb(N)
cardinals = gc_cardinal(x, cheb_nodes)
lg_cards = lg_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='CGL')
plt.plot(x, lg_cards[0, :], 'g', label='LGL')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lobatto-constrained Gaussian quadrature

# %%
def gauss_cheb_extrema(nodes):
    # Chebyshev nodal points
    s = np.arange(nodes)
    cheb_nodes = -np.cos(s * np.pi / (nodes-1))
    return cheb_nodes

def cgl_cardinal(x, cheb_nodes):
    N = cheb_nodes.shape[0]
    alpha, beta = 2 * np.ones(N), np.ones(N)
    alpha[0], alpha[-1] = 1.0, 1.0
    beta[0], beta[-1] = 0.5, 0.5
    print(cheb_nodes)
    return np.array([
        alpha[j] * sum(beta[s] * poly.chebyshev.chebval(cheb_nodes[j], (*np.zeros(s), 1)) * 
            poly.chebyshev.chebval(x, (*np.zeros(s), 1)) for s in range(N)) 
         for j in range(N)]) * 1.0 / (N-1)

lgl_nodes = {
    1: [0],
    2: [-1, 1],
    3: [-1, 0, 1],
    4: [-1, -np.sqrt(1 / 5), np.sqrt(1 / 5), 1],
    5: [-1, -np.sqrt(3 / 7), 0, np.sqrt(3 / 7), 1],
    6: [-1, -np.sqrt(1 / 3 + 2 * np.sqrt(7) / 21), -np.sqrt(1 / 3 - 2 * np.sqrt(7) / 21),
        np.sqrt(1 / 3 - 2 * np.sqrt(7) / 21), np.sqrt(1 / 3 + 2 * np.sqrt(7) / 21), 1],
    7: [-1, -0.830223896278566929872, -0.468848793470714213803772,
        0, 0.468848793470714213803772, 0.830223896278566929872, 1],
    8: [-1, -0.8717401485096066153375, -0.5917001814331423021445,
        -0.2092992179024788687687, 0.2092992179024788687687,
        0.5917001814331423021445, 0.8717401485096066153375, 1],
    9: [-1, -0.8997579954114601573124, -0.6771862795107377534459,
        -0.3631174638261781587108, 0, 0.3631174638261781587108,
        0.6771862795107377534459, 0.8997579954114601573124, 1],
    10: [-1, -0.9195339081664588138289, -0.7387738651055050750031,
         -0.4779249498104444956612, -0.1652789576663870246262,
         0.1652789576663870246262, 0.4779249498104444956612,
         0.7387738651055050750031, 0.9195339081664588138289, 1]
}

lgl_weights = {
    1: [2],
    2: [1, 1],
    3: [1 / 3, 4 / 3, 1 / 3],
    4: [1 / 6, 5 / 6, 5 / 6, 1 / 6],
    5: [1 / 10, 49 / 90, 32 / 45, 49 / 90, 1 / 10],
    6: [1 / 15, (14 - np.sqrt(7)) / 30, (14 + np.sqrt(7)) / 30,
        (14 + np.sqrt(7)) / 30, (14 - np.sqrt(7)) / 30, 1 / 15],
    7: [0.04761904761904761904762, 0.2768260473615659480107,
        0.4317453812098626234179, 0.487619047619047619048,
        0.4317453812098626234179, 0.2768260473615659480107,
        0.04761904761904761904762],
    8: [0.03571428571428571428571, 0.210704227143506039383,
        0.3411226924835043647642, 0.4124587946587038815671,
        0.4124587946587038815671, 0.3411226924835043647642,
        0.210704227143506039383, 0.03571428571428571428571],
    9: [0.02777777777777777777778, 0.1654953615608055250463,
        0.2745387125001617352807, 0.3464285109730463451151,
        0.3715192743764172335601, 0.3464285109730463451151,
        0.2745387125001617352807, 0.1654953615608055250463,
        0.02777777777777777777778],
    10: [0.02222222222222222222222, 0.1333059908510701111262,
         0.2248893420631264521195, 0.2920426836796837578756,
         0.3275397611838974566565, 0.3275397611838974566565,
         0.292042683679683757876, 0.224889342063126452119,
         0.133305990851070111126, 0.02222222222222222222222]
}

def lgl_cardinal(x, N):
    nodes, weights = (np.array(lgl_nodes.get(N, "nothing")),
                      np.array(lgl_weights.get(N, "nothing")))
    eigs = np.array([s + 0.5 for s in range(N-1)])
    eigs = np.append(eigs, (N-1)/2)
    return np.array([
        weights[j] * sum(eigs[s] * poly.legendre.legval(nodes[j], (*np.zeros(s), 1)) * 
                         poly.legendre.legval(x, (*np.zeros(s), 1)) for s in range(N))
        for j in range(N)])

x = np.linspace(-1, 1, num=100)

# %%
N = 3
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.000000e+00 -6.123234e-17  1.000000e+00]

# %%
N = 4
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.  -0.5  0.5  1. ]

# %%
N = 5
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.00000000e+00 -7.07106781e-01 -6.12323400e-17  7.07106781e-01
#   1.00000000e+00]

# %%
N = 6
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.         -0.80901699 -0.30901699  0.30901699  0.80901699  1.        ]

# %%
N = 7
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.00000000e+00 -8.66025404e-01 -5.00000000e-01 -6.12323400e-17
#   5.00000000e-01  8.66025404e-01  1.00000000e+00]

# %%
N = 8
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.         -0.90096887 -0.6234898  -0.22252093  0.22252093  0.6234898
#   0.90096887  1.        ]

# %%
N = 9
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)


plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.00000000e+00 -9.23879533e-01 -7.07106781e-01 -3.82683432e-01
#  -6.12323400e-17  3.82683432e-01  7.07106781e-01  9.23879533e-01
#   1.00000000e+00]

# %%
N = 10
x = np.linspace(-1, 1, num=1000)
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)

plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.         -0.93969262 -0.76604444 -0.5        -0.17364818  0.17364818
#   0.5         0.76604444  0.93969262  1.        ]

# %%
N = 10
x = np.linspace(-1, 1, num=1000)
cheb_nodes = gauss_cheb_extrema(N)
cardinals = cgl_cardinal(x, cheb_nodes)
lg_cards = lgl_cardinal(x, N)

plt.figure()
plt.plot(x, cardinals[0, :], 'r', label='Chebyshev-Gauss-Lobatto')
plt.plot(x, lg_cards[0, :], 'g', label='Legendre-Gauss-Lobatto')
for i in range(1, N):
    plt.plot(x, cardinals[i, :], 'r')
    plt.plot(x, lg_cards[i, :], 'g')
plt.grid(True), plt.legend(loc='best'), plt.tight_layout()
plt.show()
# Out:
# [-1.         -0.93969262 -0.76604444 -0.5        -0.17364818  0.17364818
#   0.5         0.76604444  0.93969262  1.        ]
